# %% [markdown]
# <a href="https://colab.research.google.com/github/joaobottrel/Teste_Day_6_Previsao_Vendas/blob/main/day_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas  as pd
import numpy   as np
import seaborn as sns
from google.colab import drive

# %% [markdown]
# #1. Importando Dados

# %%
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
link = '/content/gdrive/MyDrive/Colab Notebooks/Bases/features.csv'
df_f = pd.read_csv(link,decimal=',')

# %%
link2 = '/content/gdrive/MyDrive/Colab Notebooks/Bases/train.csv'
df_t = pd.read_csv(link2,decimal=',')

# %%
link3 = '/content/gdrive/MyDrive/Colab Notebooks/Bases/stores.csv'
df_s = pd.read_csv(link3,decimal=',')

# %%
df_f.head()
# Out:
#    Store        Date Temperature  ...          CPI Unemployment IsHoliday
# 0      1  2010-02-05       42.31  ...  211.0963582        8.106     False
# 1      1  2010-02-12       38.51  ...  211.2421698        8.106      True
# 2      1  2010-02-19       39.93  ...  211.2891429        8.106     False
# 3      1  2010-02-26       46.63  ...  211.3196429        8.106     False
# 4      1  2010-03-05        46.5  ...  211.3501429        8.106     False
#
# [5 rows x 12 columns]

# %%
df_t.head()
# Out:
#    Store  Dept        Date Weekly_Sales  IsHoliday
# 0      1     1  2010-02-05      24924.5      False
# 1      1     1  2010-02-12     46039.49       True
# 2      1     1  2010-02-19     41595.55      False
# 3      1     1  2010-02-26     19403.54      False
# 4      1     1  2010-03-05      21827.9      False

# %%
df_s.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %% [markdown]
# #2. Juntando os datasets

# %%
df_merge = df_f.merge(df_t,how='inner',on=['Store','Date','IsHoliday'])

# %%
df_merge.head()
# Out:
#    Store        Date Temperature  ... IsHoliday Dept Weekly_Sales
# 0      1  2010-02-05       42.31  ...     False    1      24924.5
# 1      1  2010-02-05       42.31  ...     False    2     50605.27
# 2      1  2010-02-05       42.31  ...     False    3     13740.12
# 3      1  2010-02-05       42.31  ...     False    4     39954.04
# 4      1  2010-02-05       42.31  ...     False    5     32229.38
#
# [5 rows x 14 columns]

# %%
df_merge2 = df_merge.merge(df_s,how='inner',on='Store')

# %%
df_merge2.sample(5)
# Out:
#         Store        Date  Temperature  ...  Weekly_Sales Type    Size
# 182813     19  2011-08-12        70.92  ...       5617.45    A  203819
# 169938     18  2010-10-29        55.85  ...       4597.84    B  120653
# 420497     45  2012-07-13        79.97  ...      24567.81    B  118221
# 320108     33  2012-08-24        89.62  ...      24498.53    A   39690
# 77053       8  2012-05-18        64.16  ...      14132.53    A  155078
#
# [5 rows x 16 columns]

# %%
df_merge2.shape
# Out:
# (421570, 16)

# %%
df_merge2.dtypes
# Out:
# Store            int64
# Date            object
# Temperature     object
# Fuel_Price      object
# MarkDown1       object
# MarkDown2       object
# MarkDown3       object
# MarkDown4       object
# MarkDown5       object
# CPI             object
# Unemployment    object
# IsHoliday         bool
# Dept             int64
# Weekly_Sales    object
# Type            object
# Size             int64
# dtype: object

# %%
df_merge2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 421570 entries, 0 to 421569
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Date          421570 non-null  object
#  2   Temperature   421570 non-null  object
#  3   Fuel_Price    421570 non-null  object
#  4   MarkDown1     150681 non-null  object
#  5   MarkDown2     111248 non-null  object
#  6   MarkDown3     137091 non-null  object
#  7   MarkDown4     134967 non-null  object
#  8   MarkDown5     151432 non-null  object
#  9   CPI           421570 non-null  object
#  10  Unemployment  421570 non-null  object
#  11  IsHoliday     421570 non-null  bool
#  12  Dept          421570 non-null  int64
#  13  Weekly_Sales  421570 non-null  object
#  14  Type          421570 non-null  object
#  15  Size          421570 non-null  int64
# dtypes: bool(1), int64(3), object(12)
# memory usage: 51.9+ MB

# %%
df_merge2.isnull().sum()
# Out:
# Store                0
# Date                 0
# Temperature          0
# Fuel_Price           0
# MarkDown1       270889
# MarkDown2       310322
# MarkDown3       284479
# MarkDown4       286603
# MarkDown5       270138
# CPI                  0
# Unemployment         0
# IsHoliday            0
# Dept                 0
# Weekly_Sales         0
# Type                 0
# Size                 0
# dtype: int64

# %%
df_merge2.describe(include='all')
# Out:
#                 Store        Date  ...    Type           Size
# count   421570.000000      421570  ...  421570  421570.000000
# unique            NaN         143  ...       3            NaN
# top               NaN  2011-12-23  ...       A            NaN
# freq              NaN        3027  ...  215478            NaN
# mean        22.200546         NaN  ...     NaN  136727.915739
# std         12.785297         NaN  ...     NaN   60980.583328
# min          1.000000         NaN  ...     NaN   34875.000000
# 25%         11.000000         NaN  ...     NaN   93638.000000
# 50%         22.000000         NaN  ...     NaN  140167.000000
# 75%         33.000000         NaN  ...     NaN  202505.000000
# max         45.000000         NaN  ...     NaN  219622.000000
#
# [11 rows x 16 columns]

# %%
df_merge2['Weekly_Sales']=df_merge2['Weekly_Sales'].astype('float64')
df_merge2['Temperature']=df_merge2['Temperature'].astype('float64')
df_merge2['Fuel_Price']=df_merge2['Fuel_Price'].astype('float64')
df_merge2['MarkDown1']=df_merge2['MarkDown1'].astype('float64')
df_merge2['MarkDown2']=df_merge2['MarkDown2'].astype('float64')
df_merge2['MarkDown3']=df_merge2['MarkDown3'].astype('float64')
df_merge2['MarkDown4']=df_merge2['MarkDown4'].astype('float64')
df_merge2['MarkDown5']=df_merge2['MarkDown5'].astype('float64')
df_merge2['CPI']=df_merge2['CPI'].astype('float64')
df_merge2['Unemployment']=df_merge2['Unemployment'].astype('float64')
df_merge2['Size']=df_merge2['Size'].astype('float64')

# %%
# !pip install pandas-profiling==2.7.1

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(df_merge2, minimal = True)

# %%
profile

# %%
df_merge2.corr()
# Out:
#                  Store  Temperature  ...  Weekly_Sales      Size
# Store         1.000000    -0.050097  ...     -0.085195 -0.182881
# Temperature  -0.050097     1.000000  ...     -0.002312 -0.058313
# Fuel_Price    0.065290     0.143859  ...     -0.000120  0.003361
# MarkDown1    -0.119588    -0.040594  ...      0.085251  0.345673
# MarkDown2    -0.035173    -0.323927  ...      0.024130  0.108827
# MarkDown3    -0.031556    -0.096880  ...      0.060385  0.048913
# MarkDown4    -0.009941    -0.063947  ...      0.045414  0.168196
# MarkDown5    -0.026634    -0.017544  ...      0.090362  0.304575
# CPI          -0.211088     0.182112  ...     -0.020921 -0.003314
# Unemployment  0.208552     0.096730  ...     -0.025864 -0.068238
# IsHoliday    -0.000548    -0.155949  ...      0.012774  0.000593
# Dept          0.024004     0.004437  ...      0.148032 -0.002966
# Weekly_Sales -0.085195    -0.002312  ...      1.000000  0.243828
# Size         -0.182881    -0.058313  ...      0.243828  1.000000
#
# [14 rows x 14 columns]

# %%
df_merge2.fillna(0,inplace=True)

# %%
df_merge2.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  ...  Dept  Weekly_Sales  Type    Size
# 0      1  2010-02-05        42.31       2.572  ...     1      24924.50     A  151315
# 1      1  2010-02-05        42.31       2.572  ...     2      50605.27     A  151315
# 2      1  2010-02-05        42.31       2.572  ...     3      13740.12     A  151315
# 3      1  2010-02-05        42.31       2.572  ...     4      39954.04     A  151315
# 4      1  2010-02-05        42.31       2.572  ...     5      32229.38     A  151315
#
# [5 rows x 16 columns]

# %%
sns.heatmap(df_merge2.corr())

# %%
df_clean = df_merge2.drop(columns='Date')

# %%
df_clean.head()
# Out:
#    Store  Temperature  Fuel_Price  MarkDown1  ...  Dept  Weekly_Sales  Type      Size
# 0      1        42.31       2.572        0.0  ...     1      24924.50     A  151315.0
# 1      1        42.31       2.572        0.0  ...     2      50605.27     A  151315.0
# 2      1        42.31       2.572        0.0  ...     3      13740.12     A  151315.0
# 3      1        42.31       2.572        0.0  ...     4      39954.04     A  151315.0
# 4      1        42.31       2.572        0.0  ...     5      32229.38     A  151315.0
#
# [5 rows x 15 columns]

# %%
df_final = pd.get_dummies(df_clean,columns=['IsHoliday','Type','Store','Dept'],drop_first=True)

# %%
df_final.head()
# Out:
#    Temperature  Fuel_Price  MarkDown1  ...  Dept_97  Dept_98  Dept_99
# 0        42.31       2.572        0.0  ...        0        0        0
# 1        42.31       2.572        0.0  ...        0        0        0
# 2        42.31       2.572        0.0  ...        0        0        0
# 3        42.31       2.572        0.0  ...        0        0        0
# 4        42.31       2.572        0.0  ...        0        0        0
#
# [5 rows x 138 columns]

# %%
df_final.dtypes
# Out:
# Temperature    float64
# Fuel_Price     float64
# MarkDown1      float64
# MarkDown2      float64
# MarkDown3      float64
#                 ...
# Dept_95          uint8
# Dept_96          uint8
# Dept_97          uint8
# Dept_98          uint8
# Dept_99          uint8
# Length: 138, dtype: object

# %% [markdown]
# #3. Modelo

# %%
df_final2 = df_final.sample(1000,random_state=100)

# %%
X= df_final2.drop(columns='Weekly_Sales')
y= df_final2['Weekly_Sales'].reset_index(drop=True)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_num = X.select_dtypes(['float64'])

# %%
X_num.head()
# Out:
#         Temperature  Fuel_Price  MarkDown1  ...         CPI  Unemployment      Size
# 124242        47.41       3.567       0.00  ...  129.793677         6.392  219622.0
# 6119          75.80       3.467       0.00  ...  216.375825         7.962  151315.0
# 420889        75.71       3.807    3657.79  ...  191.228492         8.684  118221.0
# 359495        64.05       4.121      24.75  ...  131.037548        11.627   39690.0
# 337459        35.80       3.422    5956.88  ...  140.646136         8.744  103681.0
#
# [5 rows x 10 columns]

# %%
X_cat = X.select_dtypes(exclude='float64')

# %%
X_cat.head()
# Out:
#         IsHoliday_True  Type_B  Type_C  ...  Dept_97  Dept_98  Dept_99
# 124242               0       0       0  ...        0        0        0
# 6119                 0       0       0  ...        0        0        0
# 420889               0       1       0  ...        0        0        0
# 359495               0       0       1  ...        0        0        0
# 337459               0       1       0  ...        0        0        0
#
# [5 rows x 127 columns]

# %%
X_numscaler = scaler.fit_transform(X_num)

# %%
X_numscaler = pd.DataFrame(X_numscaler, columns = X_num.columns)

# %%
X_numscaler.head()
# Out:
#    Temperature  Fuel_Price  MarkDown1  ...       CPI  Unemployment      Size
# 0    -0.661523    0.491983  -0.440456  ... -1.036608     -0.835829  1.392399
# 1     0.860735    0.275252  -0.440456  ...  1.179040     -0.027476  0.283018
# 2     0.855909    1.012137   0.271122  ...  0.535516      0.344264 -0.254465
# 3     0.230706    1.692672  -0.435641  ... -1.004778      1.859541 -1.529895
# 4    -1.284045    0.177724   0.718382  ... -0.758893      0.375156 -0.490611
#
# [5 rows x 10 columns]

# %%
X_final = pd.concat([X_numscaler,X_cat.reset_index(drop=True)],axis=1)

# %%
X_final.head()
# Out:
#    Temperature  Fuel_Price  MarkDown1  ...  Dept_97  Dept_98  Dept_99
# 0    -0.661523    0.491983  -0.440456  ...        0        0        0
# 1     0.860735    0.275252  -0.440456  ...        0        0        0
# 2     0.855909    1.012137   0.271122  ...        0        0        0
# 3     0.230706    1.692672  -0.435641  ...        0        0        0
# 4    -1.284045    0.177724   0.718382  ...        0        0        0
#
# [5 rows x 137 columns]

# %% [markdown]
# #4. Separação Treino e Teste

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_final, y, test_size=0.20, random_state=10)

# %% [markdown]
# #5. Escolha do Modelo

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import GradientBoostingRegressor 
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import HuberRegressor

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error

# %%
models = {'LinearRegression' : LinearRegression(),
          'SGDRegressor': SGDRegressor(),
          'GradientBoostingRegressor' : GradientBoostingRegressor(),
          'ExtraTreesRegressor' : ExtraTreesRegressor(),
          'RandomForestRegressor' : RandomForestRegressor(),
          'HuberRegressor' : HuberRegressor()}

for reg, modelo in zip(models.values(),models.keys()):
  regressor = reg
  regressor.fit(X_train, y_train)
  y_pred = regressor.predict(X_test)
  print(modelo)
  print('RMSE = {}'.format(mean_squared_error(y_test, y_pred, squared = False)))
  print("R² = {}".format(r2_score(y_test, y_pred)))
  print('MAE = {}\n'.format(mean_absolute_error(y_test, y_pred)))
# Out:
# LinearRegression
# RMSE = 15846.054278931759
# R² = 0.5920320195801707
# MAE = 10054.273549999998
#
# SGDRegressor
# RMSE = 16307.005019375842
# R² = 0.567951790254988
# MAE = 9962.995764201849
#
# GradientBoostingRegressor
# RMSE = 15242.299895201875
# R² = 0.6225279457984236
# MAE = 10038.656134894863
#
# ExtraTreesRegressor
# RMSE = 13206.317184594429
# R² = 0.7166343209972533
# MAE = 6733.374030499998
#
# RandomForestRegressor
# RMSE = 14368.652252348655
# R² = 0.664559212841245
# MAE = 8649.268811
#
# HuberRegressor
# RMSE = 16856.091476562953
# R² = 0.538366242996642
# MAE = 9145.687863073334

# %% [markdown]
# #6. Hiperparametrização

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {'n_estimators':[10,50,100,200,500],'max_depth': range(3, 10), 'criterion': ['mse','mae','squared_error','absolute_error']} 
reg = ExtraTreesRegressor()
grd = GridSearchCV(reg, parameters, scoring = 'neg_mean_absolute_error')
grd.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0,
#                                            criterion='mse', max_depth=None,
#                                            max_features='auto',
#                                            max_leaf_nodes=None,
#                                            max_samples=None,
#                                            min_impurity_decrease=0.0,
#                                            min_impurity_split=None,
#                                            min_samples_leaf=1,
#                                            min_samples_split=2,
#                                            min_weight_fraction_leaf=0.0,
#                                            n_estimators=100, n_jobs=None,
#                                            oob_score=False, random_state=None,
#                                            verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'criterion': ['mse', 'mae', 'squared_error',
#                                        'absolute_error'],
#                          'max_depth': range(3, 10),
#                          'n_estimators': [10, 50, 100, 200, 500]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='neg_mean_absolute_error', verbose=0)

# %%
grd_best = grd.best_estimator_ 
grd = ExtraTreesRegressor()
grd_best.fit(X_train, y_train)
grd.fit(X_train, y_train)
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=None, oob_score=False,
#                     random_state=None, verbose=0, warm_start=False)

# %%
y_pred = grd.predict(X_test)

# %%
print('RMSE = {}'.format(mean_squared_error(y_test, y_pred, squared = False)))
print("R² = {}".format(r2_score(y_test, y_pred)))
print('MAE = {}\n'.format(mean_absolute_error(y_test, y_pred)))
# Out:
# RMSE = 12974.111204968858
# R² = 0.7265115232777095
# MAE = 6565.266738499998

# %%
y_pred_best = grd_best.predict(X_test)

# %%
print('RMSE = {}'.format(mean_squared_error(y_test, y_pred_best, squared = False)))
print("R² = {}".format(r2_score(y_test, y_pred_best)))
print('MAE = {}\n'.format(mean_absolute_error(y_test, y_pred)))
# Out:
# RMSE = 17050.63662963333
# R² = 0.5276488267311699
# MAE = 6565.266738499998

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(y_pred, y_test)
plt.scatter(y_pred, y_test, color='black', lw=2) 
plt.plot(y_test,y_test)
